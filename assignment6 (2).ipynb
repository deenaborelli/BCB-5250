# %% [markdown]
# ## Problem 7

# %%
DNA ="..."
count_A = DNA.count("A")
count_C = DNA.count("C")
count_G = DNA.count("G")
count_T = DNA.count("T")
print(count_A,count_C,count_G,count_T)

#reference:https://www.jianshu.com/p/fb2e1d850a9f
# Out:
# 235 253 234 241

# %% [markdown]
# ## Problem 8

# %%
def reverse(seq):
    dict = {'A': 'T', 'C': 'G', 'T': 'A', 'G': 'C'}
 
    revSeqList = list(reversed(seq))               
    ComSeqList = [dict[k] for k in revSeqList]  
    ComSeq = ''.join(ComSeqList)             
    return ComSeq
 
 
seq = '...'
 
 
print (reverse(seq))

#reference:https://www.cnblogs.com/think-and-do/p/7255726.html
# Out:
# ...
